# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
#load file 
df = pd.read_csv('responses.csv')
df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
#mengubah string menjadi angka di Smoking  
df["Smoking"] = df["Smoking"].replace('current smoker', 3)  
df["Smoking"] = df["Smoking"].replace('former smoker', 2) 
df["Smoking"] = df["Smoking"].replace('tried smoking', 1)   
df["Smoking"] = df["Smoking"].replace('never smoked', 0)
#mengubah string menjadi angka di Alcohol
df["Alcohol"] = df["Alcohol"].replace('drink a lot', 2)  
df["Alcohol"] = df["Alcohol"].replace('social drinker', 1)    
df["Alcohol"] = df["Alcohol"].replace('never', 0)

# %%
#drop data
newDf = df.dropna()
print(newDf.isna().values.any())
# Out:
# False

# %%
#declare dataset feature and target 
feature = newDf[["Music","Slow songs or fast songs","Dance","Folk","Country","Classical music","Musical","Pop","Rock","Metal or Hardrock","Punk","Hiphop, Rap","Reggae, Ska","Swing, Jazz","Rock n roll","Alternative","Latino","Techno, Trance","Opera"]]
target = newDf[["Smoking","Alcohol","Healthy eating"]]
x, y = np.array(feature), np.array(target)

# %%
#memasukkan angka 1 di setiap kolom pertama feature
x = sm.add_constant(x)

# %%
#print x and y 
print(x)
print(y)
# Out:
# [[1. 5. 3. ... 1. 1. 1.]
#  [1. 4. 4. ... 2. 1. 1.]
#  [1. 5. 5. ... 5. 1. 3.]
#  ...
#  [1. 4. 3. ... 1. 1. 1.]
#  [1. 5. 3. ... 2. 2. 1.]
#  [1. 5. 5. ... 2. 3. 1.]]
# [[0. 2. 4.]
#  [0. 2. 3.]
#  [1. 2. 3.]
#  ...
#  [1. 1. 2.]
#  [1. 1. 3.]
#  [1. 1. 3.]]

# %%
#memanggil fungsi OLS dari statmodels
model = sm.OLS(y, x)

# %%
#model fit untuk mengeluarkan 
r_sq = model.fit()

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)# hasil R-Squared (bila di bawah 0.5 maka feature tidak berpengaruh kepada target)
print('intercept:', model.intercept_)# hasil coefficient pada b0 (bila di atas 0.05 maka feature tidak berpengaruh kepada target)
print('slope:', model.coef_)# hasil coefficient pada bias setelah b0 yakni b1 b2 b3(bila di atas 0.05 maka feature tidak berpengaruh kepada target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-85b1477cff77> in <module>
# ----> 1 r_sq = model.score(x, y)
#       2 print('coefficient of determination:', r_sq)
#       3 print('intercept:', model.intercept_)
#       4 print('slope:', model.coef_)
#       5
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in score(self, params, scale)
#     903             self._setup_score_hess()
#     904
# --> 905         xtxb = np.dot(self._wexog_xprod, params)
#     906         sdr = -self._wexog_x_wendog + xtxb
#     907
#
# ValueError: shapes (20,20) and (674,20) not aligned: 20 (dim 1) != 674 (dim 0)
