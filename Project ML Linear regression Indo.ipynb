# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
#import dataset
df = pd.read_csv('response indo.csv')
df
# Out:
#     Age (umur) Occupation (Pekerjaan)  Music  Slow songs or fast songs  Dance  \
# 0           19              Mahasiswa      3                         3      1
# 1           19              Mahasiswa      5                         3      5
# 2           20              Mahasiswa      5                         2      1
# 3           19              Mahasiswa      5                         2      3
# 4           19              Mahasiswa      5                         3      4
# ..         ...                    ...    ...                       ...    ...
# 70          20              Mahasiswa      5                         3      4
# 71          20              Mahasiswa      5                         3      2
# 72          20              Mahasiswa      4                         4      2
# 73          21              Mahasiswa      5                         3      5
# 74          19              Mahasiswa      5                         3      4
#
#     Folk  Country  Classical music  Musical  Pop  ...  Reggae, Ska  \
# 0      1        1                1        4    5  ...            1
# 1      4        4                4        5    4  ...            4
# 2      2        1                5        5    4  ...            1
# 3      3        4                4        4    4  ...            2
# 4      4        3                3        3    4  ...            3
# ..   ...      ...              ...      ...  ...  ...          ...
# 70     3        4                2        3    4  ...            1
# 71     2        3                2        3    5  ...            3
# 72     1        1                3        2    4  ...            1
# 73     3        3                3        3    4  ...            3
# 74     2        2                3        3    4  ...            1
#
#     Swing, Jazz  Rock n roll  Alternative  Latino  Techno, Trance  Opera  \
# 0             4            1            1       1               1      1
# 1             5            5            5       4               5      4
# 2             3            1            1       1               1      3
# 3             5            3            3       4               3      3
# 4             4            3            3       3               3      3
# ..          ...          ...          ...     ...             ...    ...
# 70            3            3            2       1               1      2
# 71            4            3            3       4               4      4
# 72            5            1            2       1               5      1
# 73            3            3            5       2               4      2
# 74            2            3            4       1               2      2
#
#            Smoking         Alcohol  Healthy eating
# 0     never smoked           never               2
# 1   current smoker           never               2
# 2     never smoked  social drinker               5
# 3     never smoked           never               4
# 4     never smoked           never               4
# ..             ...             ...             ...
# 70    never smoked  social drinker               3
# 71    never smoked           never               3
# 72    never smoked  social drinker               4
# 73    never smoked  social drinker               1
# 74    never smoked  social drinker               3
#
# [75 rows x 24 columns]

# %%
#mengubah string menjadi angka di Smoking  
df["Smoking"] = df["Smoking"].replace('current smoker', 3)  
df["Smoking"] = df["Smoking"].replace('former smoker', 2) 
df["Smoking"] = df["Smoking"].replace('tried smoking', 1)   
df["Smoking"] = df["Smoking"].replace('never smoked', 0)
#mengubah string menjadi angka di Alcohol
df["Alcohol"] = df["Alcohol"].replace('drink a lot', 2)  
df["Alcohol"] = df["Alcohol"].replace('social drinker', 1)    
df["Alcohol"] = df["Alcohol"].replace('never', 0)

# %%
#drop data
newDf = df.dropna()
print(newDf.isna().values.any())
# Out:
# False

# %%
#declare feature dan target
feature = newDf[["Music","Slow songs or fast songs","Dance","Folk","Country","Classical music","Musical","Pop","Rock","Metal or Hardrock","Punk","Hiphop, Rap","Reggae, Ska","Swing, Jazz","Rock n roll","Alternative","Latino","Techno, Trance","Opera"]]
target = newDf[["Smoking","Alcohol","Healthy eating"]]

# %%
from sklearn.linear_model import LinearRegression
x, y = np.array(feature), np.array(target)

# %%
#mengapply linear regression dan fit
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)# hasil R-Squared (bila di bawah 0.5 maka feature tidak berpengaruh kepada target)
